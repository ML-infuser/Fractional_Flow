# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('data.xlsx')
df
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2   Unnamed: 3   Unnamed: 4  Unnamed: 5  \
# 0     TABLE 1        NaN        NaN          NaN          NaN         NaN
# 1         NaN        NaN        NaN          NaN          NaN         NaN
# 2         NaN        NaN        NaN          NaN       Case 1      Case 2
# 3          Sw        Krw        Kro      Kro/Krw  Mw/Mo = .01  Mw/Mo = .1
# 4          .2          0       .800  10000000000          NaN         NaN
# 5         .25       .002       0.61      305.000          NaN         NaN
# 6         .30       .009       .470       52.222          NaN         NaN
# 7         .35       .020       .370       18.500          NaN         NaN
# 8         .40       .033       .285        8.636          NaN         NaN
# 9         .45       .051       .220        4.314          NaN         NaN
# 10        .50       .075       .163        2.173          NaN         NaN
# 11        .55        0.1       .120        1.200          NaN         NaN
# ...

# %%
X = df.iloc[3:,:4]
X
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2   Unnamed: 3
# 3          Sw        Krw        Kro      Kro/Krw
# 4          .2          0       .800  10000000000
# 5         .25       .002       0.61      305.000
# 6         .30       .009       .470       52.222
# 7         .35       .020       .370       18.500
# 8         .40       .033       .285        8.636
# 9         .45       .051       .220        4.314
# 10        .50       .075       .163        2.173
# 11        .55        0.1       .120        1.200
# 12        .60       .132       .081         .614
# 13        .65       0.17       .050         .294
# 14        .70      0.208       .027         0.13
# 15        .75       .251       .010         .040
# 16        .80       .300          0            0

# %%
#CASE 1

# %%
krkw1 = np.array(X['Unnamed: 3'][1:]).astype(float)
mwmo1 = 0.01
krkw1
# Out:
# array([1.0000e+10, 3.0500e+02, 5.2222e+01, 1.8500e+01, 8.6360e+00,
#        4.3140e+00, 2.1730e+00, 1.2000e+00, 6.1400e-01, 2.9400e-01,
#        1.3000e-01, 4.0000e-02, 0.0000e+00])

# %%
n = len(krkw1)
fw1 = []
for i in range(n):
  x = 1/(1+krkw1[i]*mwmo1)
  fw1.append(x)

# %%
fw1 = np.array(fw1)
fw1
# Out:
# array([9.99999990e-09, 2.46913580e-01, 6.56935266e-01, 8.43881857e-01,
#        9.20505173e-01, 9.58644094e-01, 9.78732150e-01, 9.88142292e-01,
#        9.93897470e-01, 9.97068618e-01, 9.98701688e-01, 9.99600160e-01,
#        1.00000000e+00])

# %%
#CASE 2

# %%
krkw2 = np.array(X['Unnamed: 3'][1:]).astype(float)
mwmo2 = 0.1
krkw2
# Out:
# array([1.0000e+10, 3.0500e+02, 5.2222e+01, 1.8500e+01, 8.6360e+00,
#        4.3140e+00, 2.1730e+00, 1.2000e+00, 6.1400e-01, 2.9400e-01,
#        1.3000e-01, 4.0000e-02, 0.0000e+00])

# %%
n = len(krkw2)
fw2 = []
for i in range(n):
  x = 1/(1+krkw2[i]*mwmo2)
  fw2.append(x)

# %%
fw2 = np.array(fw2)
fw2
# Out:
# array([9.99999999e-10, 3.17460317e-02, 1.60714860e-01, 3.50877193e-01,
#        5.36595836e-01, 6.98616739e-01, 8.21490183e-01, 8.92857143e-01,
#        9.42151875e-01, 9.71439674e-01, 9.87166831e-01, 9.96015936e-01,
#        1.00000000e+00])

# %%
#CASE 3

# %%
krkw3 = np.array(X['Unnamed: 3'][1:]).astype(float)
mwmo3 = 2.5
mwmo3
# Out:
# 2.5

# %%
n = len(krkw3)
fw3 = []
for i in range(n):
  x = 1/(1+(krkw3[i]*mwmo3))
  fw3.append(x)

# %%
fw3 = np.array(fw3)
fw3
# Out:
# array([4.00000000e-11, 1.30975769e-03, 7.60138345e-03, 2.11640212e-02,
#        4.42673749e-02, 8.48536275e-02, 1.55460552e-01, 2.50000000e-01,
#        3.94477318e-01, 5.76368876e-01, 7.54716981e-01, 9.09090909e-01,
#        1.00000000e+00])

# %%
x = np.array(X['Unnamed: 0'][1:]).astype(float)
x.shape,fw1.shape
# Out:
# ((13,), (13,))

# %%
fig,ax = plt.subplots()
ax.set_xlabel('Sw')
ax.set_ylabel('Fw')
ax.plot(x,fw1)
ax.plot(x,fw2)
ax.plot(x,fw3)
ax.set_xlim(0,1)
ax.set_ylim(0,1)
# Out:
# (0.0, 1.0)
